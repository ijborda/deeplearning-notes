# %%
# Prerequisites

import os

# Ensure Latest fastai is used if in Kaggle
iskaggle = os.environ.get('KAGGLE_KERNEL_RUN_TYPE', '')
if iskaggle:
    # !pip install -Uqq fastai 'duckduckgo_search>=6.2'
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 69.6 MB/s eta 0:00:00:00:0100:01
